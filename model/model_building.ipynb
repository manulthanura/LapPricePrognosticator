# %%
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in d:\github\lappriceprognosticator\env\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in d:\github\lappriceprognosticator\env\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\github\lappriceprognosticator\env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\github\lappriceprognosticator\env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\github\lappriceprognosticator\env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\github\lappriceprognosticator\env\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\github\lappriceprognosticator\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# Importing the libraries
import numpy as np
import pandas as pd

# %%
# Importing the dataset
url = "../dataset/laptop_price.csv"
data = pd.read_csv(url, encoding='latin-1')
data.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %%
# data.shape
# data.isnull().sum()
data.info() # check for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %% [markdown]
# ## Data Preprocessing

# %%
# Remove GB from Ram and convert it to integer
data['Ram'] = data['Ram'].str.replace('GB', '').astype('int32')

# Remove kg from Weight and convert it to float
data['Weight'] = data['Weight'].str.replace('kg', '').astype('float32')

# %%
def add_company(inpt):
    if inpt == 'Samsung' or inpt == 'Razer' or inpt == 'Mediacom' or inpt == 'Microsoft'or inpt == 'Xiaomi'or inpt == 'Vero'or inpt == 'Chuwi'or inpt == 'Google'or inpt == 'Fujitsu'or inpt == 'LG'or inpt == 'Huawei':
        return 'Other'
    else:
        return inpt
    
data['Company'] = data['Company'].apply(add_company)

# %%
data['Company'].value_counts()
# Out:
# Company
# Dell       297
# Lenovo     297
# HP         274
# Asus       158
# Acer       103
# MSI         54
# Other       51
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
len(data['Product'].value_counts())
# Out:
# 618

# %%
data['Touchscreen'] = data['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
data['Ips'] = data['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
data.head(2)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
#
#                      ScreenResolution                   Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz    8
# 1                            1440x900  Intel Core i5 1.8GHz    8
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0    0

# %%
data['cpu_name'] = data['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

def set_processor(name):
    if name == 'Intel Core i7' or name == 'Intel Core i5' or name == 'Intel Core i3':
        return name
    else:
        if name.split()[0] == 'AMD':
            return 'AMD'
        else:
            return 'Other'
        
data['cpu_name'] = data['cpu_name'].apply(set_processor)

data['cpu_name'].value_counts()
# Out:
# cpu_name
# Intel Core i7    527
# Intel Core i5    423
# Other            155
# Intel Core i3    136
# AMD               62
# Name: count, dtype: int64

# %%
# GPU company
data['gpu_name'] = data['Gpu'].apply(lambda x:" ".join(x.split()[0:1]))
data['gpu_name'].value_counts()

# Remove ARM from GPU
data = data[data['gpu_name'] != 'ARM']

# %%
# OS Data
def set_os(inpt):
    if inpt == 'Windows 10' or inpt == 'Windows 7' or inpt == 'Windows 10 S':
        return 'Windows'
    elif inpt == 'macOS' or inpt == 'Mac OS X':
        return 'Mac'
    elif inpt == 'Linux':
        return inpt
    else:
        return 'Other'
data['OpSys'] = data['OpSys'].apply(set_os)
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows    1125
# Other        94
# Linux        62
# Mac          21
# Name: count, dtype: int64

# %%
# Remove unnecessary columns

data = data.drop(columns=['laptop_ID', 'Inches', 'Product', 'ScreenResolution', 'Cpu', 'Gpu'])

data.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8    Mac    1.37      1339.69            0    1
# 1   Apple  Ultrabook    8    Mac    1.34       898.94            0    0
# 2      HP   Notebook    8  Other    1.86       575.00            0    0
# 3   Apple  Ultrabook   16    Mac    1.83      2537.45            0    1
# 4   Apple  Ultrabook    8    Mac    1.37      1803.60            0    1
#
#         cpu_name gpu_name
# 0  Intel Core i5    Intel
# 1  Intel Core i5    Intel
# 2  Intel Core i5    Intel
# 3  Intel Core i7      AMD
# 4  Intel Core i5    Intel

# %%
# one hot encoding
data = pd.get_dummies(data)
data.head(2)
data.shape
# Out:
# (1302, 32)

# %% [markdown]
# # Model Building

# %%
X = data.drop('Price_euros', axis=1)
y = data['Price_euros']

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\github\lappriceprognosticator\env\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in d:\github\lappriceprognosticator\env\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in d:\github\lappriceprognosticator\env\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\github\lappriceprognosticator\env\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\github\lappriceprognosticator\env\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
X_train.shape, X_test.shape
# Out:
# ((976, 31), (326, 31))

# %%
# Model accuracy test

def model_acc(model):
    model.fit(X_train, y_train)
    acc = model.score(X_test, y_test)
    print(str(model)+ ' --> '+ str(acc))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model_acc(lr)

from sklearn.linear_model import Lasso
ls = Lasso()
model_acc(ls)

from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
model_acc(dt)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
model_acc(rf)
# Out:
# LinearRegression() --> 0.6876008367377824
# Lasso() --> 0.6905090272239747
# DecisionTreeRegressor() --> 0.6469326840672014
# RandomForestRegressor() --> 0.7613295838589762

# %%
# Use Random Forest Regressor

# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_estimators': [10, 50, 100],
    'criterion': ['squared_error', 'absolute_error', 'poisson']
}

grid_obj = GridSearchCV(estimator=rf, param_grid=parameters)
grid_fit = grid_obj.fit(X_train, y_train)
best_fit = grid_fit.best_estimator_
best_fit
# Out:
# RandomForestRegressor(criterion='absolute_error', n_estimators=10)

# %%
best_fit.score(X_train, y_train)
# Out:
# 0.9486296452289981

# %% [markdown]
# ### Save Model

# %%
import pickle
with open('predictor.pickle', 'wb') as file:
    pickle.dump(best_fit, file)

# %%
X_train.columns
# Out:
# Index(['Ram', 'Weight', 'Touchscreen', 'Ips', 'Company_Acer', 'Company_Apple',
#        'Company_Asus', 'Company_Dell', 'Company_HP', 'Company_Lenovo',
#        'Company_MSI', 'Company_Other', 'Company_Toshiba',
#        'TypeName_2 in 1 Convertible', 'TypeName_Gaming', 'TypeName_Netbook',
#        'TypeName_Notebook', 'TypeName_Ultrabook', 'TypeName_Workstation',
#        'OpSys_Linux', 'OpSys_Mac', 'OpSys_Other', 'OpSys_Windows',
#        'cpu_name_AMD', 'cpu_name_Intel Core i3', 'cpu_name_Intel Core i5',
#        'cpu_name_Intel Core i7', 'cpu_name_Other', 'gpu_name_AMD',
#        'gpu_name_Intel', 'gpu_name_Nvidia'],
#       dtype='object')
